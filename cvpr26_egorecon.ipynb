# %%
# %load_ext autoreload
# %autoreload 2
import os 
import numpy as np
from table import *

# %%
table = parse_table(data["Obj"])
print(table)
# Out:
# {'FP+HAWOR-simple': {'All': {'ADD': 0.301, 'ADD-S': 0.447, 'Center': 0.367, 'ACC-NORM': 0.896}, 'Contact': {'ADD': 0.387, 'ADD-S': 0.575, 'Center': 0.481}, 'Truncated': {'ADD': 0.194, 'ADD-S': 0.289, 'Center': 0.232}, 'Out-of-view': {'ADD': 0.083, 'ADD-S': 0.137, 'Center': 0.099}}, 'FP+HAWOR-contact': {'All': {'ADD': 0.309, 'ADD-S': 0.458, 'Center': 0.375, 'ACC-NORM': 0.627}, 'Contact': {'ADD': 0.396, 'ADD-S': 0.586, 'Center': 0.49}, 'Truncated': {'ADD': 0.201, 'ADD-S': 0.333, 'Center': 0.249}, 'Out-of-view': {'ADD': 0.088, 'ADD-S': 0.169, 'Center': 0.104}}, 'Ours': {'All': {'ADD': 0.511, 'ADD-S': 0.699, 'Center': 0.58, 'ACC-NORM': 0.11}, 'Contact': {'ADD': 0.558, 'ADD-S': 0.773, 'Center': 0.65}, 'Truncated': {'ADD': 0.425, 'ADD-S': 0.602, 'Center': 0.49}, 'Out-of-view': {'ADD': 0.288, 'ADD-S': 0.438, 'Center': 0.305}}}

# %%
method_list = ["FP+HAWOR-simple", "FP+HAWOR-contact", "Ours"]
category_list = ["All", "Contact", "Truncated", "Out-of-view"]
metrics = [["ADD", "ADD-S", "ACC-NORM"]] + [["ADD", "ADD-S"]] * 3
format_dict = {"ADD": lambda x: f"{x*100:.1f}", "ADD-S": lambda x: f"{x*100:.1f}", "ACC-NORM": lambda x: f"{x:.3f}"}

ret = print_table(table, method_list, category_list, metrics, format_dict)
# Out:
# method & \multicolumn{3}{c}{All} & \multicolumn{2}{c}{Contact} & \multicolumn{2}{c}{Truncated} & \multicolumn{2}{c}{Out-of-view} \\
# \cmidrule(r){2-4} \cmidrule(r){5-6} \cmidrule(r){7-8} \cmidrule(r){9-10} \\
#   & ADD & ADD-S & ACC-NORM & ADD & ADD-S & ADD & ADD-S & ADD & ADD-S \\
# \midrule
# FP+HAWOR-simple & 30.1 & 44.7 & 0.896 & 38.7 & 57.5 & 19.4 & 28.9 & 8.3 & 13.7 \\
# FP+HAWOR-contact & 30.9 & 45.8 & 0.627 & 39.6 & 58.6 & 20.1 & 33.3 & 8.8 & 16.9 \\
# Ours & \first \textbf{51.1} & \first \textbf{69.9} & \first \textbf{0.11} & \first \textbf{55.8} & \first \textbf{77.3} & \first \textbf{42.5} & \first \textbf{60.2} & \first \textbf{28.8} & \first \textbf{43.8} \\

# %%
table = parse_table(data["HOI"])
print(table)

method_list = ["FP+HAWOR-simple", "FP+HAWOR-contact", "Ours"]
category_list = ["All", "Contact", "Truncated", "Out-of-view"]
metrics = [["ADD", "ADD-S", "ACC-NORM"]] + [["ADD", "ADD-S"]] * 3
format_dict = {"ADD": lambda x: f"{x*100:.1f}", "ADD-S": lambda x: f"{x*100:.1f}", "ACC-NORM": lambda x: f"{x:.3f}"}

ret = print_table(table, method_list, category_list, metrics, format_dict)
# Out:
# {'FP+HAWOR-simple': {'All': {'ADD': 0.3, 'ADD-S': 0.451, 'Center': 0.365, 'ACC-NORM': 0.896}, 'Contact': {'ADD': 0.379, 'ADD-S': 0.571, 'Center': 0.471}, 'Truncated': {'ADD': 0.183, 'ADD-S': 0.298, 'Center': 0.22}, 'Out-of-view': {'ADD': 0.088, 'ADD-S': 0.172, 'Center': 0.104}}, 'FP+HAWOR-contact': {'All': {'ADD': 0.389, 'ADD-S': 0.568, 'Center': 0.482, 'ACC-NORM': 0.627}, 'Contact': {'ADD': 0.496, 'ADD-S': 0.719, 'Center': 0.624}, 'Truncated': {'ADD': 0.284, 'ADD-S': 0.48, 'Center': 0.386}, 'Out-of-view': {'ADD': 0.084, 'ADD-S': 0.201, 'Center': 0.096}}, 'Ours': {'All': {'ADD': 0.535, 'ADD-S': 0.723, 'Center': 0.608, 'ACC-NORM': 0.11}, 'Contact': {'ADD': 0.58, 'ADD-S': 0.794, 'Center': 0.676}, 'Truncated': {'ADD': 0.443, 'ADD-S': 0.627, 'Center': 0.517}, 'Out-of-view': {'ADD': 0.28, 'ADD-S': 0.432, 'Center': 0.295}}}
# method & \multicolumn{3}{c}{All} & \multicolumn{2}{c}{Contact} & \multicolumn{2}{c}{Truncated} & \multicolumn{2}{c}{Out-of-view} \\
# \cmidrule(r){2-4} \cmidrule(r){5-6} \cmidrule(r){7-8} \cmidrule(r){9-10} \\
#   & ADD & ADD-S & ACC-NORM & ADD & ADD-S & ADD & ADD-S & ADD & ADD-S \\
# \midrule
# FP+HAWOR-simple & 30.0 & 45.1 & 0.896 & 37.9 & 57.1 & 18.3 & 29.8 & 8.8 & 17.2 \\
# FP+HAWOR-contact & 38.9 & 56.8 & 0.627 & 49.6 & 71.9 & 28.4 & 48.0 & 8.4 & 20.1 \\
# Ours & \first \textbf{53.5} & \first \textbf{72.3} & \first \textbf{0.11} & \first \textbf{58.0} & \first \textbf{79.4} & \first \textbf{44.3} & \first \textbf{62.7} & \first \textbf{28.0} & \first \textbf{43.2} \\

# %%
from table import *
table = parse_table(data["Hand"], hand_metrics, category_hand)
print(table)

method_list = ["HaWoR", "FP+HAWOR-simple", "FP+HAWOR-contact", "Ours"]
category_list = ["All"]
metrics = [["WA-MPJPE",  "W-MPJPE",  "Accel", "PA-MPJPE"]]
format_dict = {"WA-MPJPE": lambda x: f"{x*100:.2f}", "W-MPJPE": lambda x: f"{x*100:.2f}", "Accel": lambda x: f"{x*100:.2f}", "PA-MPJPE": lambda x: f"{x*1000:.2f}"}

ret = print_table(table, method_list, category_list, metrics, format_dict)
# Out:
# {'HaWoR': {'All': {'PA-MPJPE': 0.00899, 'W-MPJPE': 0.11256, 'WA-MPJPE': 0.0376, 'Accel': 0.037594}, 'Contact': {}, 'Truncated': {}, 'Out-of-view': {}}, 'FP+HAWOR-simple': {'All': {'PA-MPJPE': 0.00899, 'W-MPJPE': 0.10675, 'WA-MPJPE': 0.03926, 'Accel': 0.01094}, 'Contact': {}, 'Truncated': {}, 'Out-of-view': {}}, 'FP+HAWOR-contact': {'All': {'PA-MPJPE': 0.00899, 'W-MPJPE': 0.18894, 'WA-MPJPE': 0.07903, 'Accel': 0.0152}, 'Contact': {}, 'Truncated': {}, 'Out-of-view': {}}, 'Ours': {'All': {'PA-MPJPE': 0.00667, 'W-MPJPE': 0.10412, 'WA-MPJPE': 0.03263, 'Accel': 0.00577}, 'Contact': {}, 'Truncated': {}, 'Out-of-view': {}}}
# method & \multicolumn{4}{c}{All} \\
# \cmidrule(r){2-5} \\
#   & WA-MPJPE & W-MPJPE & Accel & PA-MPJPE \\
# \midrule
# HaWoR & 3.76 & 11.26 & 3.76 & 8.99 \\
# FP+HAWOR-simple & 3.93 & 10.67 & 1.09 & 8.99 \\
# FP+HAWOR-contact & 7.90 & 18.89 & 1.52 & 8.99 \\
# Ours & \first \textbf{3.26} & \first \textbf{10.41} & \first \textbf{0.58} & \first \textbf{6.67} \\

# %%
from table import *
metric_list = ["PA-MPJPE", "W-MPJPE", "WA-MPJPE", "Accel", "ADD-obj", "ADDI-obj", "Center-obj", "ACC-obj", "ADD-hoi", "ADDI-hoi", "Center-hoi", "ACC-hoi"]
category_list = ["ablation"]
table = parse_table(data["Ablation"], metric_list, category_list)
print(table)

method_list = ["GT-contact", "no-guidance", "no-contact", "ours"]
metric_list = ["WA-MPJPE", "W-MPJPE", "Accel",  "PA-MPJPE", "ADD-obj", "ADDI-obj",  "ACC-obj", "ADD-hoi", "ADDI-hoi", "ACC-hoi"]
# category_list = ["Hand", "Object", "Interaction"]
format_dict = {"WA-MPJPE": lambda x: f"{x*100:.2f}", "W-MPJPE": lambda x: f"{x*100:.2f}", "Accel": lambda x: f"{x*100:.2f}", "PA-MPJPE": lambda x: f"{x*1000:.2f}", "ADD-obj": lambda x: f"{x*100:.1f}", "ADDI-obj": lambda x: f"{x*100:.1f}", "ACC-obj": lambda x: f"{x:.2f}", "ADD-hoi": lambda x: f"{x*100:.1f}", "ADDI-hoi": lambda x: f"{x*100:.1f}", "ACC-hoi": lambda x: f"{x:.2f}"}

ret = print_table(table, method_list, category_list, [metric_list], format_dict, no_first=True)
# Out:
# {'ours': {'ablation': {'PA-MPJPE': 0.00667, 'W-MPJPE': 0.10412, 'WA-MPJPE': 0.03263, 'Accel': 0.00577, 'ADD-obj': 0.511, 'ADDI-obj': 0.699, 'Center-obj': 0.58, 'ACC-obj': 0.11, 'ADD-hoi': 0.535, 'ADDI-hoi': 0.723, 'Center-hoi': 0.608, 'ACC-hoi': 0.11}}, 'GT-contact': {'ablation': {'PA-MPJPE': 0.006612, 'W-MPJPE': 0.107923, 'WA-MPJPE': 0.032779, 'Accel': 0.005518, 'ADD-obj': 0.537, 'ADDI-obj': 0.7217142222, 'Center-obj': 0.6047577778, 'ACC-obj': 0.07040227205, 'ADD-hoi': 0.561, 'ADDI-hoi': 0.745, 'Center-hoi': 0.6313971111, 'ACC-hoi': 0.07040216029}}, 'no-guidance': {'ablation': {'PA-MPJPE': 0.009345, 'W-MPJPE': 0.159229, 'WA-MPJPE': 0.04595, 'Accel': 0.007592, 'ADD-obj': 0.443, 'ADDI-obj': 0.6104111111, 'Center-obj': 0.50978, 'ACC-obj': 0.1332766414, 'ADD-hoi': 0.45, 'ADDI-hoi': 0.6212884444, 'Center-hoi': 0.5224046667, 'ACC-hoi': 0.1332766414}}, 'no-contact': {'ablation': {'PA-MPJPE': 0.006703, 'W-MPJPE': 0.104701, 'WA-MPJPE': 0.031221, 'Accel': 0.006099, 'ADD-obj': 0.285, 'ADDI-obj': 0.4294973333, 'Center-obj': 0.3207328889, 'ACC-obj': 0.08681160212, 'ADD-hoi': 0.306, 'ADDI-hoi': 0.4547377778, 'Center-hoi': 0.3449206667, 'ACC-hoi': 0.08681152016}}}
# method & \multicolumn{10}{c}{ablation} \\
# \cmidrule(r){2-11} \\
#   & WA-MPJPE & W-MPJPE & Accel & PA-MPJPE & ADD-obj & ADDI-obj & ACC-obj & ADD-hoi & ADDI-hoi & ACC-hoi \\
# \midrule
# GT-contact & 3.28 & 10.79 & 0.55 & 6.61 & 53.7 & 72.2 & 0.07 & 56.1 & 74.5 & 0.07 \\
# no-guidance & 4.59 & 15.92 & 0.76 & 9.34 & 44.3 & 61.0 & 0.13 & 45.0 & 62.1 & 0.13 \\
# no-contact & 3.12 & 10.47 & 0.61 & 6.70 & 28.5 & 42.9 & 0.09 & 30.6 & 45.5 & 0.09 \\
# ours & 3.26 & 10.41 & 0.58 & 6.67 & 51.1 & 69.9 & 0.11 & 53.5 & 72.3 & 0.11 \\
